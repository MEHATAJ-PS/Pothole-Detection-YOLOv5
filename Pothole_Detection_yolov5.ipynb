# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17516, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 17516 (delta 6), reused 0 (delta 0), pack-reused 17497 (from 4)
# Receiving objects: 100% (17516/17516), 16.62 MiB | 20.88 MiB/s, done.
# Resolving deltas: 100% (12001/12001), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 44.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 30.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 23.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.6 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
# !ls /content/yolov5/runs/train/pothole_model
# Out:
# events.out.tfevents.1753067823.63494c38ef79.5304.0  hyp.yaml  opt.yaml	weights

# %%
# !ls -R /content/yolov5/runs/train/pothole_model
# Out:
# /content/yolov5/runs/train/pothole_model:
# events.out.tfevents.1753067823.63494c38ef79.5304.0  hyp.yaml  opt.yaml	weights
#
# /content/yolov5/runs/train/pothole_model/weights:

# %%
# !ls -R /content/dataset
# Out:
# /content/dataset:
# images	labels	train  valid
#
# /content/dataset/images:
# train  val
#
# /content/dataset/images/train:
# 100.jpg  107.jpg  113.jpg  11.jpg   127.jpg  133.jpg  13.jpg   146.jpg	152.jpg
# 101.jpg  108.jpg  114.jpg  120.jpg  128.jpg  134.jpg  140.jpg  147.jpg	15.jpg
# 102.jpg  109.jpg  115.jpg  121.jpg  129.jpg  135.jpg  141.jpg  148.jpg	16.jpg
# 103.jpg  10.jpg   116.jpg  122.jpg  12.jpg   136.jpg  142.jpg  149.jpg	1.jpg
# 104.jpg  110.jpg  117.jpg  123.jpg  130.jpg  137.jpg  143.jpg  14.jpg
# 105.jpg  111.jpg  118.jpg  125.jpg  131.jpg  138.jpg  144.jpg  150.jpg
# 106.jpg  112.jpg  119.jpg  126.jpg  132.jpg  139.jpg  145.jpg  151.jpg
#
# /content/dataset/images/val:
# 153.jpg  156.jpg  160.jpg  163.jpg  168.jpg  177.jpg  201.jpg
# 154.jpg  157.jpg  161.jpg  164.jpg  172.jpg  189.jpg  209.jpg
# 155.jpg  159.jpg  162.jpg  166.jpg  175.jpg  194.jpg
#
# /content/dataset/labels:
# train  val
#
# /content/dataset/labels/train:
# ...

# %%
# Create necessary folders
# !mkdir -p /content/dataset/train/images
# !mkdir -p /content/dataset/train/labels
# !mkdir -p /content/dataset/val/images
# !mkdir -p /content/dataset/val/labels

# Copy files to expected locations
# !cp /content/dataset/images/train/* /content/dataset/train/images/
# !cp /content/dataset/labels/train/* /content/dataset/train/labels/
# !cp /content/dataset/images/val/* /content/dataset/val/images/
# !cp /content/dataset/labels/val/* /content/dataset/val/labels/

# %%
# !unzip dataset-20250721T042655Z-1-001.zip -d /content/
# Out:
# Archive:  dataset-20250721T042655Z-1-001.zip
#   inflating: /content/dataset/labels/val/168.txt
#   inflating: /content/dataset/labels/val/175.txt
#   inflating: /content/dataset/labels/val/160.txt
#   inflating: /content/dataset/labels/val/153.txt
#   inflating: /content/dataset/labels/val/194.txt
#   inflating: /content/dataset/labels/val/177.txt
#   inflating: /content/dataset/labels/val/164.txt
#   inflating: /content/dataset/labels/val/189.txt
#   inflating: /content/dataset/labels/val/162.txt
#   inflating: /content/dataset/labels/val/155.txt
#   inflating: /content/dataset/labels/val/201.txt
#   inflating: /content/dataset/labels/val/159.txt
#   inflating: /content/dataset/labels/val/156.txt
#   inflating: /content/dataset/labels/val/209.txt
#   inflating: /content/dataset/labels/val/157.txt
#   inflating: /content/dataset/labels/train/134.txt
#   inflating: /content/dataset/labels/train/150.txt
#   inflating: /content/dataset/labels/train/147.txt
# ...

# %%
# !ls /content
# Out:
# dataset  drive	sample_data  yolov5

# %%
from google.colab import files
uploaded = files.upload()  # upload a .zip file of your dataset
# Out:
#      <input type="file" id="files-e26eaec5-702d-4cba-96ae-927ec78490a6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e26eaec5-702d-4cba-96ae-927ec78490a6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls /content/dataset/train/images | wc -l
# !ls /content/dataset/val/images | wc -l
# Out:
# 60
# 20

# %%
# !python /content/yolov5/train.py --img 640 --batch 16 --epochs 20 --data /content/yolov5/data/pothole.yaml --weights yolov5s.pt --name pothole_model
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-07-21 05:42:35.200767: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753076555.226328   40937 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753076555.233934   40937 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-26cea9f5-2f32-4b6d-8000-53b4f98b551e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-26cea9f5-2f32-4b6d-8000-53b4f98b551e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !python /content/yolov5/detect.py \
  --weights /content/yolov5/runs/train/pothole_model6/weights/best.pt \
  --img 640 \
  --conf 0.25 \
  --source "/content/test-img2.jpg"
# Out:
# detect: weights=['/content/yolov5/runs/train/pothole_model6/weights/best.pt'], source=/content/test-img2.jpg, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-422-g2540fd4c Python-3.11.13 torch-2.6.0+cu124 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/test-img2.jpg: 480x640 (no detections), 320.9ms
# Speed: 3.2ms pre-process, 320.9ms inference, 0.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov5/runs/detect/exp9
